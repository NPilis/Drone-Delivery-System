# %%
import numpy as np
import random
from matplotlib import pyplot as plt

class Client:
    
    def __init__(self, id, x, y):
        self.id = id
        self.x = x
        self.y = y
    
    def __repr__(self):
        return 'Client {}:  position: ({}, {})'.format(self.id, self.x, self.y)
    
    def get_distance_from_drone(self, drone):
        return np.sqrt((drone.x-self.x)**2 + (drone.y-self.y)**2)
        

class Drone:
    
    def __init__(self, id):
        self.id = id
        self.velocity = 60
        self.num_of_packages = 4
        self.battery = 100
        self.temp_client_id = None
        
        self.x = 0
        self.y = 0
        self.x_client = None
        self.y_client = None
        self.x_prev_client = None
        self.x_prev_client = None
    
    def __repr__(self):
        return 'Drone {}:  battery: {}%  position: ({}, {})  packages: {}'.format(self.id, self.battery, self.x, self.y, self.num_of_packages)
    
    def change_position(self, x, y):
        self.x = x
        self.y = y
    
    def discharge(self):
        self.battery -= 1
    
    def charge(self):
        self.battery += 1
    
    # Euclidian distance
    def get_distance_from_client(self):
        return np.sqrt((self.x_client-self.x)**2 + (self.y_client-self.y)**2)
    
    def deliver_package(self):
        self.num_of_packages -= 1
        self.x_prev_client = self.x_client
        self.y_prev_client = self.y_client
        self.temp_client_id = None
        self.x_client = None
        self.y_client = None

    def load_packages(self):
        self.num_of_packages = 4
    
    def specify_client(self, client):
        if (self.temp_client_id == None):
            self.temp_client_id = client.id
            self.x_client = client.x
            self.y_client = client.y
    
    def travel(self):
        distance = self.get_distance_from_client()
        if (distance < 1):
            self.x = self.x_client
            self.y = self.y_client
            self.deliver_package()
        else:
            w = abs(self.x - self.x_client)
            h = abs(self.y - self.y_client)
            sin_alpha = h/distance
            sin_beta = w/distance
            if (self.x >= self.x_client and self.y >= self.y_client):
                self.change_position(self.x - sin_beta, self.y - sin_alpha)
            if (self.x <= self.x_client and self.y <= self.y_client):
                self.change_position(self.x + sin_beta, self.y + sin_alpha)
            if (self.x >= self.x_client and self.y <= self.y_client):
                self.change_position(self.x - sin_beta, self.y + sin_alpha)
            if (self.x <= self.x_client and self.y >= self.y_client):
                self.change_position(self.x + sin_beta, self.y - sin_alpha)
        self.discharge()

class TabuSearch:
    
    def __init__(self, drones, clients):
        self.drones = drones
        self.clients = clients
        self.total_time = 0
        
        # For visualization ...
        self.x_clients = []
        self.y_clients = []
        self.x_visited = []
        self.y_visited = []
        self.x_drones = []
        self.y_drones = []
    
    def initialize_client_positions(self):
        for client in self.clients:
            self.x_clients.append(client.x)
            self.y_clients.append(client.y)
    
    def update_drone_positions(self):
        self.x_drones = []
        self.y_drones = []
        for drone in self.drones:
            self.x_drones.append(drone.x)
            self.y_drones.append(drone.y)
    
    def update_visited_clients(self, x, y):
        self.x_visited.append(x)
        self.y_visited.append(y)
    
    def assign_clients(self):
        for drone in self.drones:
            drone.specify_client(self.clients.pop())
    
    def assign_client(self, drone_id):
        for drone in self.drones:
            if (drone.id == drone_id):
                drone.specify_client(self.clients.pop())

# %%
# Need for figure outside jupyter
# %matplotlib qt

# %%
# Creating drones
d1 = Drone(1)
d2 = Drone(2)
d3 = Drone(3)
drones = [d1, d2, d3]

# Creating clients with random (x, y) positions
clients = []
for i in range(100):
    x_pos = 0
    y_pos = 0
    while (y_pos == 0 and x_pos == 0):
        x_pos = random.randint(-25,25)
        y_pos = random.randint(-25,25)
    c = Client(i+1, x_pos, y_pos)
    clients.append(c)

# Initialization and assignment of structures 
ts1 = TabuSearch(drones, clients)
ts1.initialize_client_positions()
ts1.update_drone_positions()
ts1.assign_clients()

# %%
fig = plt.figure(figsize=(12,12))

k = 1
for i in range(1000):
    if k == 4:
        k = 1
    else:
        k = k+1
    for drone in ts1.drones:
        if drone.temp_client_id == None:
            ts1.assign_client(drone.id)
            ts1.update_visited_clients(drone.x_prev_client, drone.y_prev_client)
        drone.travel()
    ts1.update_drone_positions()
    plt.plot(ts1.x_clients, ts1.y_clients, 'go', markersize=12)
    plt.plot(ts1.x_drones, ts1.y_drones, 'm{}'.format(k), markersize=20)
    plt.plot(ts1.x_visited, ts1.y_visited, 'ro', markersize=12, linewidth=4)
    plt.plot(ts1.x_visited, ts1.y_visited, 'wx', markersize=12)
    plt.ylim(-30, 30)
    plt.xlim(-30, 30)
    plt.title(f'FRAME {i+1}')
    
    plt.draw()
    plt.pause(0.01)
    plt.cla()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\matplotlib\backends\backend_qt5agg.py in paintEvent(self, event)
#      56         reg = self.copy_from_bbox(bbox)
#      57         buf = cbook._unmultiplied_rgba8888_to_premultiplied_argb32(
# ---> 58             memoryview(reg))
#      59
#      60         # clear the widget canvas
#
# ~\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py in _unmultiplied_rgba8888_to_premultiplied_argb32(rgba8888)
#    2127     """
#    2128     if sys.byteorder == "little":
# -> 2129         argb32 = np.take(rgba8888, [2, 1, 0, 3], axis=2)
#    2130         rgb24 = argb32[..., :-1]
#    2131         alpha8 = argb32[..., -1:]
#
# <__array_function__ internals> in take(*args, **kwargs)
#
# ~\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in take(a, indices, axis, out, mode)
#     192            [5, 7]])
#     193     """
# --> 194     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     195
#     196
#
# ~\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\matplotlib\backends\backend_qt5.py in _draw_idle(self)
#     506                 return
#     507             try:
# --> 508                 self.draw()
#     509             except Exception:
#     510                 # Uncaught exceptions are fatal for PyQt5, so catch them.
#
# ~\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1409         while len(self.majorTicks) < numticks:
#    1410             # Update the new tick label properties from the old.
# -> 1411             tick = self._get_tick(major=True)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
# --> 160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#     162         self.label2 = self._get_text2()
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_gridline(self)
#     493                           **self._grid_kw)
#     494         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
# --> 495         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#     496         self._set_artist_props(l)
#     497
#
# ~\Anaconda\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# ~\Anaconda\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     677             y = self._y
#     678
# --> 679         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     680         self._x, self._y = self._xy.T  # views
#     681
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-328-e0820074e513> in <module>
#      23     plt.draw()
#      24     plt.pause(0.01)
# ---> 25     plt.cla()
#      26 plt.show()
#
# ~\Anaconda\lib\site-packages\matplotlib\pyplot.py in cla()
#    2492 @docstring.copy(Axes.cla)
#    2493 def cla():
# -> 2494     return gca().cla()
#    2495
#    2496
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     975
#     976         for name, spine in self.spines.items():
# --> 977             spine.cla()
#     978
#     979         self.ignore_existing_data_limits = True
#
# ~\Anaconda\lib\site-packages\matplotlib\spines.py in cla(self)
#     228         self._position = None  # clear position
#     229         if self.axis is not None:
# --> 230             self.axis.cla()
#     231
#     232     @cbook.deprecated("3.1")
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in cla(self)
#     833                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     834
# --> 835         self.reset_ticks()
#     836
#     837         self.converter = None
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     856             pass
#     857         try:
# --> 858             self.set_clip_path(self.axes.patch)
#     859         except AttributeError:
#     860             pass
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     945     def set_clip_path(self, clippath, transform=None):
#     946         martist.Artist.set_clip_path(self, clippath, transform)
# --> 947         for child in self.majorTicks + self.minorTicks:
#     948             child.set_clip_path(clippath, transform)
#     949         self.stale = True
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     667             if self._major:
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157
#     158         self.tick1line = self._get_tick1line()
# --> 159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_tick2line(self)
#     478                           zorder=self._zorder)
#     479
# --> 480         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#     481         self._set_artist_props(l)
#     482         return l
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in get_xaxis_transform(self, which)
#     678         elif which == 'tick2':
#     679             # for cartesian projection, this is top spine
# --> 680             return self.spines['top'].get_spine_transform()
#     681         else:
#     682             raise ValueError('unknown value for which')
#
# ~\Anaconda\lib\site-packages\matplotlib\spines.py in get_spine_transform(self)
#     487     def get_spine_transform(self):
#     488         """Return the spine transform."""
# --> 489         self._ensure_position_is_set()
#     490         what, how = self._spine_transform
#     491
#
# ~\Anaconda\lib\site-packages\matplotlib\spines.py in _ensure_position_is_set(self)
#     210             # default position
#     211             self._position = ('outward', 0.0)  # in points
# --> 212             self.set_position(self._position)
#     213
#     214     def register_axis(self, axis):
#
# ~\Anaconda\lib\site-packages\matplotlib\spines.py in set_position(self, position)
#     477
#     478         if self.axis is not None:
# --> 479             self.axis.reset_ticks()
#     480         self.stale = True
#     481
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     856             pass
#     857         try:
# --> 858             self.set_clip_path(self.axes.patch)
#     859         except AttributeError:
#     860             pass
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     946         martist.Artist.set_clip_path(self, clippath, transform)
#     947         for child in self.majorTicks + self.minorTicks:
# --> 948             child.set_clip_path(clippath, transform)
#     949         self.stale = True
#     950
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     231         # docstring inherited
#     232         martist.Artist.set_clip_path(self, clippath, transform)
# --> 233         self.gridline.set_clip_path(clippath, transform)
#     234         self.stale = True
#     235
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     730             if isinstance(path, Rectangle):
#     731                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 732                                                path.get_transform())
#     733                 self._clippath = None
#     734                 success = True
#
# ~\Anaconda\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# ~\Anaconda\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# ~\Anaconda\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
# --> 737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#     739         self._rect_transform += rot_trans
#
# ~\Anaconda\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    1958         # Cast to float to avoid wraparound issues with uint8's
#    1959         x, y = float(x), float(y)
# -> 1960         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1961
#    1962     def translate(self, tx, ty):
#
# ~\Anaconda\lib\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    1970         translate_mtx = np.array(
#    1971             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 1972         self._mtx = np.dot(translate_mtx, self._mtx)
#    1973         self.invalidate()
#    1974         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
